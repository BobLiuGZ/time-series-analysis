# %% [markdown]
# <a href="https://colab.research.google.com/github/BobLiuGZ/time-series-analysis/blob/master/Out_LSTM_Paper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!/usr/bin/env python
# coding: utf-8

# In[2]:


import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
import tensorflow as tf
from tensorflow.keras.layers import Dense, Activation, Dropout, Flatten, LSTM, CuDNNLSTM
from tensorflow.keras.models import Sequential, load_model
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

# In[3]:


import os
from tensorflow.python.client import device_lib

os.environ["TF_CPP_MIN_LOG_LEVEL"] = "99"

if __name__ == "__main__":
    print(device_lib.list_local_devices())

# In[4]:


config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)


# In[5]:
# The Generation of Multiple Uncorrelated Rayleigh Fading Waveforms
def Rayleigh(fd, time):
    '''
    改进的jakes模型来产生单径的平坦型瑞利衰落信道
    :param Fd: 信道的最大多普勒频移 单位Hz
    :param T: 信号的抽样时间序列，抽样间隔单位s
    :return data: 为输出的瑞利信道函数，是一个时间函数复序列

    '''
    np.random.seed(2019)
    t = []
    alfa = []
    for i in range(1, time + 1):
        t.append(i)

    length = len(t)
    # 假设的入射波数目
    n = 40
    # 每象限的入射波数目即振荡器数目
    n0 = n // 4

    wm = 2 * math.pi * fd
    # 信道函数的实部
    tc = np.zeros((1, length))
    # 信道函数的虚部
    ts = np.zeros((1, length))
    # 归一化功率系数
    p_nor = math.sqrt(1 / n0)
    # 区别个条路径的均匀分布随机相位
    theta = 2 * math.pi * np.random.rand(1, 1) - math.pi
    for ii in range(1, n0 + 1):
        # 第i条入射波的入射角
        alfa.append((2 * math.pi * ii - math.pi + theta) / n)
        # 对每个子载波而言在(-pi,pi)之间均匀分布的随机相位
        fi_tc = 2 * math.pi + np.random.rand(1, 1) - math.pi
        fi_ts = 2 * math.pi + np.random.rand(1, 1) - math.pi
        # 计算冲激响应函数
        tc = tc + np.cos(math.cos(alfa[ii - 1]) * wm * np.array(t) + fi_tc)
        ts = ts + np.cos(math.sin(alfa[ii - 1]) * wm * np.array(t) + fi_ts)

    # 乘归一化功率系数得到传输函数
    ray_data = p_nor * (tc + 1j * ts)

    return ray_data


# The plot of Real and Image part of Raleigh Fading Channel
fd = 926
t = 10000
data = Rayleigh(fd, t)
# print(Rdata.tpye)
real = data.real
imag = data.imag
plt.subplot(211)
plt.plot(real[0])
plt.xlabel('points')
plt.ylabel('Amplitude')
plt.title('The part of real ---- Fd: ' + str(fd) + ' HZ, times: ' + str(t))
plt.subplot(212)
plt.plot(imag[0])
plt.xlabel('points')
plt.ylabel('Amplitude')
plt.title('The part of Imag ---- Fd: ' + str(fd) + ' HZ, times: ' + str(t))
plt.show()

# In[6]:

Rdata = real[0].reshape(-1, 1)
print(np.shape(Rdata))
scaler = MinMaxScaler(feature_range=(0, 1))
Rdata = scaler.fit_transform(Rdata)

# In[7]:


# split into training and test
train_size = int(len(Rdata) * 0.9)
test_size = len(Rdata) - train_size
# predict_size = len(Rdata) - train_size
train, test = Rdata[0:train_size, :], Rdata[train_size:len(Rdata), :]


# In[8]:


# convert data into training dataset and Label dataset
def create_dataset(dataset, look_back):
    dataX, dataY = [], []
    for i in range(len(dataset) - look_back):
        a = dataset[i:(i + look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return np.array(dataX), np.array(dataY)


# In[9]:


look_back = 20
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)
trainX = np.reshape(trainX, (trainX.shape[0], trainX.shape[1], 1))
testX = np.reshape(testX, (testX.shape[0], testX.shape[1], 1))


# training the model
def model_building():
    model = Sequential()
    model.add(CuDNNLSTM(100))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(loss='mean_squared_error', optimizer='adam', metrics=["mean_squared_error"])
    return model


model = model_building()
model.fit(trainX, trainY, epochs=100, validation_split=0.2, batch_size=512, verbose=2)


# In[35]:


def moving_test_window_preds(n_future_preds):
    preds_moving = []  # Use this to store the prediction made on each test window
    moving_test_window = [testX[0, :].tolist()]  # Creating the first test window
    moving_test_window = np.array(moving_test_window)  # Making it an numpy array

    for i in range(n_future_preds):
        preds_one_step = model.predict(
            moving_test_window)  # Note that this is already a scaled prediction so no need to rescale this
        preds_moving.append(preds_one_step[0, 0])  # get the value from the numpy 2D array and append to predictions
        preds_one_step = preds_one_step.reshape(1, 1,
                                                1)  # Reshaping the prediction to 3D array for concatenation with moving test window
        moving_test_window = np.concatenate((moving_test_window[:, 1:, :], preds_one_step),
                                            axis=1)  # This is the new moving test window, where the first element from the window has been removed and the prediction  has been appended to the end
    #  print(preds_one_step)
    #  print(moving_test_window)
    return preds_moving


# In[36]:


Pred_Num = 10
preds_moving = moving_test_window_preds(Pred_Num)
preds_moving = np.array(preds_moving)
preds_moving = scaler.inverse_transform(preds_moving.reshape(-1, 1))
# print(np.shape(testY))
testY = scaler.inverse_transform([testY])


# In[37]:

# The Normalised Mean Square Error from Paper  Two
def NMSE_q(p, m):
    n = len(p)
    p0 = sum(p) / n
    m0 = sum(m) / n
    nmse = np.mean((p - m) ** 2) / (p0 * m0)
    return nmse


NMSE = NMSE_q(testY[0, 0:Pred_Num], preds_moving[:, 0])
PreScore = math.sqrt(mean_squared_error(testY[0, 0:Pred_Num], preds_moving[:, 0]))
# print('Test Score: %.2f RMSE' % (PreScore))
plt.figure(2)
plt.title('RMSE= %.2f' % (PreScore) + '  NMSE = %.2f' % (NMSE))
plt.plot(testY[0, 0:Pred_Num])
plt.plot(preds_moving[:, 0])
plt.xticks(np.array(range(Pred_Num)))
plt.xlabel('points')
plt.ylabel('Amplitude')
plt.legend(['Observed', 'Prediction'], loc='best')
plt.figure(3)
plt.title('Error between Observed and Prediction')
plt.xlabel('Point')
plt.xticks(np.array(range(Pred_Num)))
plt.ylabel('abs(Error)')
plt.plot(abs(preds_moving[:, 0] - testY[0, 0:Pred_Num]))
plt.show()
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 2041468395511670873
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 14964779817324577130
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 4814955666711531694
# physical_device_desc: "device: XLA_GPU device"
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 14800692839
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 13732844928063308167
# physical_device_desc: "device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5"
# ]
# (10000, 1)
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/utils/losses_utils.py:170: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 7184 samples, validate on 1796 samples
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/100
#  - 4s - loss: 0.0218 - mean_squared_error: 0.0218 - val_loss: 0.0216 - val_mean_squared_error: 0.0216
# Epoch 2/100
#  - 0s - loss: 0.0217 - mean_squared_error: 0.0217 - val_loss: 0.0216 - val_mean_squared_error: 0.0216
# Epoch 3/100
#  - 0s - loss: 0.0217 - mean_squared_error: 0.0217 - val_loss: 0.0217 - val_mean_squared_error: 0.0217
# Epoch 4/100
#  - 0s - loss: 0.0217 - mean_squared_error: 0.0217 - val_loss: 0.0214 - val_mean_squared_error: 0.0214
# Epoch 5/100
#  - 0s - loss: 0.0215 - mean_squared_error: 0.0215 - val_loss: 0.0212 - val_mean_squared_error: 0.0212
# Epoch 6/100
#  - 0s - loss: 0.0210 - mean_squared_error: 0.0210 - val_loss: 0.0200 - val_mean_squared_error: 0.0200
# Epoch 7/100
#  - 0s - loss: 0.0199 - mean_squared_error: 0.0199 - val_loss: 0.0192 - val_mean_squared_error: 0.0192
# Epoch 8/100
#  - 0s - loss: 0.0197 - mean_squared_error: 0.0197 - val_loss: 0.0193 - val_mean_squared_error: 0.0193
# Epoch 9/100
#  - 0s - loss: 0.0191 - mean_squared_error: 0.0191 - val_loss: 0.0230 - val_mean_squared_error: 0.0230
# Epoch 10/100
#  - 0s - loss: 0.0200 - mean_squared_error: 0.0200 - val_loss: 0.0195 - val_mean_squared_error: 0.0195
# Epoch 11/100
#  - 0s - loss: 0.0190 - mean_squared_error: 0.0190 - val_loss: 0.0187 - val_mean_squared_error: 0.0187
# Epoch 12/100
#  - 0s - loss: 0.0186 - mean_squared_error: 0.0186 - val_loss: 0.0184 - val_mean_squared_error: 0.0184
# Epoch 13/100
#  - 0s - loss: 0.0184 - mean_squared_error: 0.0184 - val_loss: 0.0182 - val_mean_squared_error: 0.0182
# Epoch 14/100
#  - 0s - loss: 0.0185 - mean_squared_error: 0.0185 - val_loss: 0.0186 - val_mean_squared_error: 0.0186
# Epoch 15/100
#  - 0s - loss: 0.0186 - mean_squared_error: 0.0186 - val_loss: 0.0195 - val_mean_squared_error: 0.0195
# Epoch 16/100
#  - 0s - loss: 0.0197 - mean_squared_error: 0.0197 - val_loss: 0.0194 - val_mean_squared_error: 0.0194
# Epoch 17/100
#  - 0s - loss: 0.0194 - mean_squared_error: 0.0194 - val_loss: 0.0186 - val_mean_squared_error: 0.0186
# Epoch 18/100
#  - 0s - loss: 0.0184 - mean_squared_error: 0.0184 - val_loss: 0.0185 - val_mean_squared_error: 0.0185
# Epoch 19/100
#  - 0s - loss: 0.0182 - mean_squared_error: 0.0182 - val_loss: 0.0178 - val_mean_squared_error: 0.0178
# Epoch 20/100
#  - 0s - loss: 0.0178 - mean_squared_error: 0.0178 - val_loss: 0.0183 - val_mean_squared_error: 0.0183
# Epoch 21/100
#  - 0s - loss: 0.0184 - mean_squared_error: 0.0184 - val_loss: 0.0178 - val_mean_squared_error: 0.0178
# Epoch 22/100
#  - 0s - loss: 0.0181 - mean_squared_error: 0.0181 - val_loss: 0.0178 - val_mean_squared_error: 0.0178
# Epoch 23/100
#  - 0s - loss: 0.0179 - mean_squared_error: 0.0179 - val_loss: 0.0176 - val_mean_squared_error: 0.0176
# Epoch 24/100
#  - 0s - loss: 0.0180 - mean_squared_error: 0.0180 - val_loss: 0.0174 - val_mean_squared_error: 0.0174
# Epoch 25/100
#  - 0s - loss: 0.0177 - mean_squared_error: 0.0177 - val_loss: 0.0184 - val_mean_squared_error: 0.0184
# Epoch 26/100
#  - 0s - loss: 0.0176 - mean_squared_error: 0.0176 - val_loss: 0.0191 - val_mean_squared_error: 0.0191
# Epoch 27/100
#  - 0s - loss: 0.0184 - mean_squared_error: 0.0184 - val_loss: 0.0175 - val_mean_squared_error: 0.0175
# Epoch 28/100
#  - 0s - loss: 0.0174 - mean_squared_error: 0.0174 - val_loss: 0.0171 - val_mean_squared_error: 0.0171
# Epoch 29/100
#  - 0s - loss: 0.0172 - mean_squared_error: 0.0172 - val_loss: 0.0180 - val_mean_squared_error: 0.0180
# Epoch 30/100
#  - 0s - loss: 0.0172 - mean_squared_error: 0.0172 - val_loss: 0.0184 - val_mean_squared_error: 0.0184
# Epoch 31/100
#  - 0s - loss: 0.0176 - mean_squared_error: 0.0176 - val_loss: 0.0193 - val_mean_squared_error: 0.0193
# Epoch 32/100
#  - 0s - loss: 0.0188 - mean_squared_error: 0.0188 - val_loss: 0.0176 - val_mean_squared_error: 0.0176
# Epoch 33/100
#  - 0s - loss: 0.0169 - mean_squared_error: 0.0169 - val_loss: 0.0168 - val_mean_squared_error: 0.0168
# Epoch 34/100
#  - 0s - loss: 0.0169 - mean_squared_error: 0.0169 - val_loss: 0.0165 - val_mean_squared_error: 0.0165
# Epoch 35/100
#  - 0s - loss: 0.0164 - mean_squared_error: 0.0164 - val_loss: 0.0171 - val_mean_squared_error: 0.0171
# Epoch 36/100
#  - 0s - loss: 0.0169 - mean_squared_error: 0.0169 - val_loss: 0.0201 - val_mean_squared_error: 0.0201
# Epoch 37/100
#  - 0s - loss: 0.0171 - mean_squared_error: 0.0171 - val_loss: 0.0163 - val_mean_squared_error: 0.0163
# Epoch 38/100
#  - 0s - loss: 0.0163 - mean_squared_error: 0.0163 - val_loss: 0.0165 - val_mean_squared_error: 0.0165
# Epoch 39/100
#  - 0s - loss: 0.0161 - mean_squared_error: 0.0161 - val_loss: 0.0169 - val_mean_squared_error: 0.0169
# Epoch 40/100
#  - 0s - loss: 0.0162 - mean_squared_error: 0.0162 - val_loss: 0.0156 - val_mean_squared_error: 0.0156
# Epoch 41/100
#  - 0s - loss: 0.0159 - mean_squared_error: 0.0159 - val_loss: 0.0175 - val_mean_squared_error: 0.0175
# Epoch 42/100
#  - 0s - loss: 0.0165 - mean_squared_error: 0.0165 - val_loss: 0.0157 - val_mean_squared_error: 0.0157
# Epoch 43/100
#  - 0s - loss: 0.0155 - mean_squared_error: 0.0155 - val_loss: 0.0168 - val_mean_squared_error: 0.0168
# Epoch 44/100
#  - 0s - loss: 0.0159 - mean_squared_error: 0.0159 - val_loss: 0.0150 - val_mean_squared_error: 0.0150
# Epoch 45/100
#  - 0s - loss: 0.0152 - mean_squared_error: 0.0152 - val_loss: 0.0147 - val_mean_squared_error: 0.0147
# Epoch 46/100
#  - 0s - loss: 0.0145 - mean_squared_error: 0.0145 - val_loss: 0.0491 - val_mean_squared_error: 0.0491
# Epoch 47/100
#  - 0s - loss: 0.0207 - mean_squared_error: 0.0207 - val_loss: 0.0204 - val_mean_squared_error: 0.0204
# Epoch 48/100
#  - 0s - loss: 0.0172 - mean_squared_error: 0.0172 - val_loss: 0.0154 - val_mean_squared_error: 0.0154
# Epoch 49/100
#  - 0s - loss: 0.0156 - mean_squared_error: 0.0156 - val_loss: 0.0151 - val_mean_squared_error: 0.0151
# Epoch 50/100
#  - 0s - loss: 0.0150 - mean_squared_error: 0.0150 - val_loss: 0.0147 - val_mean_squared_error: 0.0147
# Epoch 51/100
#  - 0s - loss: 0.0146 - mean_squared_error: 0.0146 - val_loss: 0.0155 - val_mean_squared_error: 0.0155
# Epoch 52/100
#  - 0s - loss: 0.0150 - mean_squared_error: 0.0150 - val_loss: 0.0141 - val_mean_squared_error: 0.0141
# Epoch 53/100
#  - 0s - loss: 0.0142 - mean_squared_error: 0.0142 - val_loss: 0.0139 - val_mean_squared_error: 0.0139
# Epoch 54/100
#  - 0s - loss: 0.0139 - mean_squared_error: 0.0139 - val_loss: 0.0148 - val_mean_squared_error: 0.0148
# Epoch 55/100
#  - 0s - loss: 0.0139 - mean_squared_error: 0.0139 - val_loss: 0.0128 - val_mean_squared_error: 0.0128
# Epoch 56/100
#  - 0s - loss: 0.0128 - mean_squared_error: 0.0128 - val_loss: 0.0121 - val_mean_squared_error: 0.0121
# Epoch 57/100
#  - 0s - loss: 0.0120 - mean_squared_error: 0.0120 - val_loss: 0.0115 - val_mean_squared_error: 0.0115
# Epoch 58/100
#  - 0s - loss: 0.0116 - mean_squared_error: 0.0116 - val_loss: 0.0134 - val_mean_squared_error: 0.0134
# Epoch 59/100
#  - 0s - loss: 0.0120 - mean_squared_error: 0.0120 - val_loss: 0.0151 - val_mean_squared_error: 0.0151
# Epoch 60/100
#  - 0s - loss: 0.0132 - mean_squared_error: 0.0132 - val_loss: 0.0128 - val_mean_squared_error: 0.0128
# Epoch 61/100
#  - 0s - loss: 0.0114 - mean_squared_error: 0.0114 - val_loss: 0.0106 - val_mean_squared_error: 0.0106
# Epoch 62/100
#  - 0s - loss: 0.0107 - mean_squared_error: 0.0107 - val_loss: 0.0102 - val_mean_squared_error: 0.0102
# Epoch 63/100
#  - 0s - loss: 0.0102 - mean_squared_error: 0.0102 - val_loss: 0.0101 - val_mean_squared_error: 0.0101
# Epoch 64/100
#  - 0s - loss: 0.0098 - mean_squared_error: 0.0098 - val_loss: 0.0104 - val_mean_squared_error: 0.0104
# Epoch 65/100
#  - 0s - loss: 0.0101 - mean_squared_error: 0.0101 - val_loss: 0.0098 - val_mean_squared_error: 0.0098
# Epoch 66/100
#  - 0s - loss: 0.0100 - mean_squared_error: 0.0100 - val_loss: 0.0093 - val_mean_squared_error: 0.0093
# Epoch 67/100
#  - 0s - loss: 0.0091 - mean_squared_error: 0.0091 - val_loss: 0.0092 - val_mean_squared_error: 0.0092
# Epoch 68/100
#  - 0s - loss: 0.0092 - mean_squared_error: 0.0092 - val_loss: 0.0084 - val_mean_squared_error: 0.0084
# Epoch 69/100
#  - 0s - loss: 0.0097 - mean_squared_error: 0.0097 - val_loss: 0.0087 - val_mean_squared_error: 0.0087
# Epoch 70/100
#  - 0s - loss: 0.0088 - mean_squared_error: 0.0088 - val_loss: 0.0083 - val_mean_squared_error: 0.0083
# Epoch 71/100
#  - 0s - loss: 0.0097 - mean_squared_error: 0.0097 - val_loss: 0.0119 - val_mean_squared_error: 0.0119
# Epoch 72/100
#  - 0s - loss: 0.0099 - mean_squared_error: 0.0099 - val_loss: 0.0093 - val_mean_squared_error: 0.0093
# Epoch 73/100
#  - 0s - loss: 0.0090 - mean_squared_error: 0.0090 - val_loss: 0.0084 - val_mean_squared_error: 0.0084
# Epoch 74/100
#  - 0s - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0079 - val_mean_squared_error: 0.0079
# Epoch 75/100
#  - 0s - loss: 0.0077 - mean_squared_error: 0.0077 - val_loss: 0.0083 - val_mean_squared_error: 0.0083
# Epoch 76/100
#  - 0s - loss: 0.0074 - mean_squared_error: 0.0074 - val_loss: 0.0070 - val_mean_squared_error: 0.0070
# Epoch 77/100
#  - 0s - loss: 0.0076 - mean_squared_error: 0.0076 - val_loss: 0.0107 - val_mean_squared_error: 0.0107
# Epoch 78/100
#  - 0s - loss: 0.0081 - mean_squared_error: 0.0081 - val_loss: 0.0126 - val_mean_squared_error: 0.0126
# Epoch 79/100
#  - 0s - loss: 0.0088 - mean_squared_error: 0.0088 - val_loss: 0.0077 - val_mean_squared_error: 0.0077
# Epoch 80/100
#  - 0s - loss: 0.0073 - mean_squared_error: 0.0073 - val_loss: 0.0065 - val_mean_squared_error: 0.0065
# Epoch 81/100
#  - 0s - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 0.0065 - val_mean_squared_error: 0.0065
# Epoch 82/100
#  - 0s - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0077 - val_mean_squared_error: 0.0077
# Epoch 83/100
#  - 0s - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 0.0059 - val_mean_squared_error: 0.0059
# Epoch 84/100
#  - 0s - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 85/100
#  - 0s - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
# Epoch 86/100
#  - 0s - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0036 - val_mean_squared_error: 0.0036
# Epoch 87/100
#  - 0s - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 88/100
#  - 0s - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0034 - val_mean_squared_error: 0.0034
# Epoch 89/100
#  - 0s - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0030 - val_mean_squared_error: 0.0030
# Epoch 90/100
#  - 0s - loss: 0.0030 - mean_squared_error: 0.0030 - val_loss: 0.0028 - val_mean_squared_error: 0.0028
# Epoch 91/100
#  - 0s - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.0041 - val_mean_squared_error: 0.0041
# Epoch 92/100
#  - 0s - loss: 0.0031 - mean_squared_error: 0.0031 - val_loss: 0.0026 - val_mean_squared_error: 0.0026
# Epoch 93/100
#  - 0s - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0026 - val_mean_squared_error: 0.0026
# Epoch 94/100
#  - 0s - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0052 - val_mean_squared_error: 0.0052
# Epoch 95/100
#  - 0s - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0060 - val_mean_squared_error: 0.0060
# Epoch 96/100
#  - 0s - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 97/100
#  - 0s - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0026 - val_mean_squared_error: 0.0026
# Epoch 98/100
#  - 0s - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
# Epoch 99/100
#  - 0s - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 100/100
#  - 0s - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0019 - val_mean_squared_error: 0.0019
